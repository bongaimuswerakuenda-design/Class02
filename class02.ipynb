# %% [markdown]
# <a href="https://colab.research.google.com/github/bongaimuswerakuenda-design/Class02/blob/main/class02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World")
print("Welcome to Machine Learning")
# Out:
# Hello, World
# Welcome to Machine Learning

# %%
name = "Bridgette"
print("Hello", name)
# Out:
# Hello Bridgette

# %%
2+3
# Out:
# 5

# %%
10*5
# Out:
# 50

# %%
100/4
# Out:
# 25.0

# %%
x=10
y=5
x+y
# Out:
# 15

# %%
name="Bridgette"
age=26
height=1.53
is_student=True

# %%
title= "Day in a life of Bridgette"
print (title)
print(title.lower())
print(title.upper())
len(title)
# Out:
# Day in a life of Bridgette
# day in a life of bridgette
# DAY IN A LIFE OF BRIDGETTE
# 26

# %%
ratings=[5,4,3,5,2]
print(ratings)
print(ratings[0])
print(ratings[2])
# Out:
# [5, 4, 3, 5, 2]
# 5
# 3

# %%
rating=5
if rating >=4:
  print("positive review")
else:
    print("Not a positive review")
# Out:
# positive review

# %%
ratings=[5,4,3,5,2]
for rating in ratings:
  print(rating)
# Out:
# 5
# 4
# 3
# 5
# 2

# %%
def greet(name) :
  print("Hello",name)
greet("Bridgette")
# Out:
# Hello Bridgette
